# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22})

df = pd.read_csv("time_series_covid19_confirmed_global.csv")
df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  3/24/20  3/25/20  3/26/20  3/27/20  \
# 0        0        0        0  ...       74       84       94      110
# 1        0        0        0  ...      123      146      174      186
# 2        0        0        0  ...      264      302      367      409
# 3        0        0        0  ...      164      188      224      267
# 4        0        0        0  ...        3        3        4        4
#
#    3/28/20  3/29/20  3/30/20  3/31/20  4/1/20  4/2/20
# ...

# %%
df.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20', '1/28/20', '1/29/20',
#        '1/30/20', '1/31/20', '2/1/20', '2/2/20', '2/3/20', '2/4/20', '2/5/20',
#        '2/6/20', '2/7/20', '2/8/20', '2/9/20', '2/10/20', '2/11/20', '2/12/20',
#        '2/13/20', '2/14/20', '2/15/20', '2/16/20', '2/17/20', '2/18/20',
#        '2/19/20', '2/20/20', '2/21/20', '2/22/20', '2/23/20', '2/24/20',
#        '2/25/20', '2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20',
#        '3/2/20', '3/3/20', '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20',
#        '3/9/20', '3/10/20', '3/11/20', '3/12/20', '3/13/20', '3/14/20',
#        '3/15/20', '3/16/20', '3/17/20', '3/18/20', '3/19/20', '3/20/20',
#        '3/21/20', '3/22/20', '3/23/20', '3/24/20', '3/25/20', '3/26/20',
#        '3/27/20', '3/28/20', '3/29/20', '3/30/20', '3/31/20', '4/1/20',
#        '4/2/20'],
#       dtype='object')

# %%
il = df.loc[df['Country/Region'] == "Israel"]
i = 0
for clmn in il:
    if i<35:
        del il[clmn]
        i+=1
    
# del il['Province/State']
# del il['Country/Region']
# del il['Lat']
# del il['Long']
il
# Out:
#      2/22/20  2/23/20  2/24/20  2/25/20  2/26/20  2/27/20  2/28/20  2/29/20  \
# 136        1        1        1        1        2        3        4        7
#
#      3/1/20  3/2/20  ...  3/24/20  3/25/20  3/26/20  3/27/20  3/28/20  \
# 136      10      10  ...     1238     2369     2693     3035     3619
#
#      3/29/20  3/30/20  3/31/20  4/1/20  4/2/20
# 136     4247     4695     5358    6092    6857
#
# [1 rows x 41 columns]

# %%
il_t = il.T
il_t.plot.bar(legend=False, figsize=(30,20))

# %%
il_t.plot.line(figsize=(30,20))

# %%
# il_t.mean()
np.mean(il_t)
# Out:
# 136    1113.02439
# dtype: float64

# %%
np.median(il_t)
# Out:
# 126.0

# %%
np.std(il_t)
# Out:
# 136    1861.352295
# dtype: float64
